# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.style.use('https://raw.githubusercontent.com/davidbetancur8/palettes/master/eafit.mplstyle')
enmax_palette = ["#000066", "#00A9E0", "#FF8F1C", "#C4D600", "#00B0B9"]

sns.set_palette(palette=enmax_palette)

# %%
df = pd.read_csv("tweets_Colombia_sentiment.csv")

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["sentiment"])
plt.savefig(f'spell7.png',bbox_inches='tight', transparent="True", pad_inches = 0)

plt.show()
